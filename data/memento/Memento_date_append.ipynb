# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import re
import numpy as np
import pandas as pd
import pickle
import random
import collections
import json
from datetime import datetime

# %%
overall_df=pd.read_excel('/content/drive/MyDrive/BIZ&AI_PAPER_11기/세희/memento/task/data/overall_data.xlsx')
train_df=pd.read_excel('/content/drive/MyDrive/BIZ&AI_PAPER_11기/세희/memento/task/data/train_data.xlsx')
test_df=pd.read_excel('/content/drive/MyDrive/BIZ&AI_PAPER_11기/세희/memento/task/data/test_data.xlsx')

# %% [markdown]
# #overall

# %%
overall_df['date'] = overall_df['contexts'].str[0:13]
overall_df
# Out:
#                date                                           contexts
# 0     2022년 12월 06일  2022년 12월 06일 21시 27분에 집에서 말했다 가게 앞에서 귀여운 고양이를 봤다
# 1     2022년 12월 06일  2022년 12월 06일 21시 27분에 집에서 말했다 가게 앞에서 귀여운 고양이를 봤다
# 2     2022년 12월 06일  2022년 12월 06일 21시 27분에 집에서 말했다 가게 앞에서 귀여운 고양이를 봤다
# 3     2022년 12월 06일  2022년 12월 06일 21시 27분에 집에서 말했다 가게 앞에서 귀여운 고양이를 봤다
# 4     2022년 12월 06일  2022년 12월 06일 21시 27분에 집에서 말했다 가게 앞에서 귀여운 고양이를 봤다
# ...             ...                                                ...
# 6615  2022년 12월 21일  2022년 12월 21일 17시 29분에 히토리우동에서 말했다 제육볶음을 먹었다 양...
# 6616  2022년 12월 21일  2022년 12월 21일 17시 29분에 히토리우동에서 말했다 제육볶음을 먹었다 양...
# 6617  2022년 12월 21일  2022년 12월 21일 17시 29분에 히토리우동에서 말했다 제육볶음을 먹었다 양...
# 6618  2022년 12월 21일  2022년 12월 21일 17시 29분에 히토리우동에서 말했다 제육볶음을 먹었다 양...
# 6619  2022년 12월 21일  2022년 12월 21일 17시 29분에 히토리우동에서 말했다 제육볶음을 먹었다 양...
#
# [6620 rows x 2 columns]

# %%
overall_df['date']=overall_df['date'].str.replace('년', '-')

# %%
overall_df['date']=overall_df['date'].str.replace('월', '-')

# %%
overall_df['date']=overall_df['date'].str.replace('일', '')

# %%
overall_df['date']=overall_df['date'].str.replace(' ', '')

# %%
overall_df['questions']=""
overall_df['answers']=""

# %%
overall_df
# Out:
#             date                                           contexts questions  \
# 0     2022-12-06  2022년 12월 06일 21시 27분에 집에서 말했다 가게 앞에서 귀여운 고양이를 봤다
# 1     2022-12-06  2022년 12월 06일 21시 27분에 집에서 말했다 가게 앞에서 귀여운 고양이를 봤다
# 2     2022-12-06  2022년 12월 06일 21시 27분에 집에서 말했다 가게 앞에서 귀여운 고양이를 봤다
# 3     2022-12-06  2022년 12월 06일 21시 27분에 집에서 말했다 가게 앞에서 귀여운 고양이를 봤다
# 4     2022-12-06  2022년 12월 06일 21시 27분에 집에서 말했다 가게 앞에서 귀여운 고양이를 봤다
# ...          ...                                                ...       ...
# 6615  2022-12-21  2022년 12월 21일 17시 29분에 히토리우동에서 말했다 제육볶음을 먹었다 양...
# 6616  2022-12-21  2022년 12월 21일 17시 29분에 히토리우동에서 말했다 제육볶음을 먹었다 양...
# 6617  2022-12-21  2022년 12월 21일 17시 29분에 히토리우동에서 말했다 제육볶음을 먹었다 양...
# 6618  2022-12-21  2022년 12월 21일 17시 29분에 히토리우동에서 말했다 제육볶음을 먹었다 양...
# 6619  2022-12-21  2022년 12월 21일 17시 29분에 히토리우동에서 말했다 제육볶음을 먹었다 양...
#
#      answers
# 0
# 1
# 2
# 3
# 4
# ...      ...
# 6615
# 6616
# 6617
# 6618
# 6619
#
# [6620 rows x 4 columns]

# %%
overall_df.to_csv("overall_data.csv", index = False)

# %% [markdown]
# # train

# %%
train_df['date'] = train_df['contexts'].str[0:13]
train_df
# Out:
#                date                                           contexts
# 0     2022년 12월 06일  2022년 12월 06일 21시 27분에 집에서 말했다 가게 앞에서 귀여운 고양이를 봤다
# 1     2022년 12월 06일  2022년 12월 06일 21시 27분에 집에서 말했다 가게 앞에서 귀여운 고양이를 봤다
# 2     2022년 12월 06일  2022년 12월 06일 21시 27분에 집에서 말했다 가게 앞에서 귀여운 고양이를 봤다
# 3     2022년 12월 06일  2022년 12월 06일 21시 27분에 집에서 말했다 가게 앞에서 귀여운 고양이를 봤다
# 4     2022년 12월 06일  2022년 12월 06일 21시 27분에 집에서 말했다 가게 앞에서 귀여운 고양이를 봤다
# ...             ...                                                ...
# 5953  2022년 12월 18일  2022년 12월 18일 06시 58분에 히토리우동에서 말했다 야채곱창을 먹었는데 ...
# 5954  2022년 12월 18일  2022년 12월 18일 06시 58분에 히토리우동에서 말했다 야채곱창을 먹었는데 ...
# 5955  2022년 12월 19일  2022년 12월 19일 06시 58분에 히토리우동에서 말했다 야채곱창을 먹었는데 ...
# 5956  2022년 12월 19일  2022년 12월 19일 13시 00분에 스시도쿠에서 말했다 동기들이랑 회랑 소주를...
# 5957  2022년 12월 19일  2022년 12월 19일 13시 00분에 스시도쿠에서 말했다 동기들이랑 회랑 소주를...
#
# [5958 rows x 2 columns]

# %%
train_df['date']=train_df['date'].str.replace('년', '-')

# %%
train_df['date']=train_df['date'].str.replace('월', '-')

# %%
train_df['date']=train_df['date'].str.replace('일', '')

# %%
train_df['date']=train_df['date'].str.replace(' ', '')

# %%
train_df['questions']=""
train_df['answers']=""

# %%
train_df
# Out:
#             date                                           contexts questions  \
# 0     2022-12-06  2022년 12월 06일 21시 27분에 집에서 말했다 가게 앞에서 귀여운 고양이를 봤다
# 1     2022-12-06  2022년 12월 06일 21시 27분에 집에서 말했다 가게 앞에서 귀여운 고양이를 봤다
# 2     2022-12-06  2022년 12월 06일 21시 27분에 집에서 말했다 가게 앞에서 귀여운 고양이를 봤다
# 3     2022-12-06  2022년 12월 06일 21시 27분에 집에서 말했다 가게 앞에서 귀여운 고양이를 봤다
# 4     2022-12-06  2022년 12월 06일 21시 27분에 집에서 말했다 가게 앞에서 귀여운 고양이를 봤다
# ...          ...                                                ...       ...
# 5953  2022-12-18  2022년 12월 18일 06시 58분에 히토리우동에서 말했다 야채곱창을 먹었는데 ...
# 5954  2022-12-18  2022년 12월 18일 06시 58분에 히토리우동에서 말했다 야채곱창을 먹었는데 ...
# 5955  2022-12-19  2022년 12월 19일 06시 58분에 히토리우동에서 말했다 야채곱창을 먹었는데 ...
# 5956  2022-12-19  2022년 12월 19일 13시 00분에 스시도쿠에서 말했다 동기들이랑 회랑 소주를...
# 5957  2022-12-19  2022년 12월 19일 13시 00분에 스시도쿠에서 말했다 동기들이랑 회랑 소주를...
#
#      answers
# 0
# 1
# 2
# 3
# 4
# ...      ...
# 5953
# 5954
# 5955
# 5956
# 5957
#
# [5958 rows x 4 columns]

# %%
train_df.to_csv("train_data.csv", index = False)

# %% [markdown]
# # test

# %%
test_df.to_csv("test_data.csv", index=False)
